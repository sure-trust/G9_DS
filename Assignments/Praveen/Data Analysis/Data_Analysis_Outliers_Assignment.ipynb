# %% [markdown]
# Outliers Assignment

# %% [markdown]
# NAME : CHINNA PRAVEEN
#
# GROUP : G9 DS
#
# TOPIC : Data Analysis-Outliers
#
# INSTRUCTOR NAME: BHARGAVESH DAKKA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/content/employees.csv")

# %%
data.describe()
# Out:
#        EMPLOYEE_ID        SALARY  DEPARTMENT_ID
# count    50.000000     50.000000       50.00000
# mean    134.760000   6182.320000       57.60000
# std      33.631594   4586.181772       25.11687
# min     100.000000   2100.000000       10.00000
# 25%     112.250000   2725.000000       50.00000
# 50%     124.500000   4600.000000       50.00000
# 75%     136.750000   8150.000000       60.00000
# max     206.000000  24000.000000      110.00000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   EMPLOYEE_ID     50 non-null     int64
#  1   FIRST_NAME      50 non-null     object
#  2   LAST_NAME       50 non-null     object
#  3   EMAIL           50 non-null     object
#  4   PHONE_NUMBER    50 non-null     object
#  5   HIRE_DATE       50 non-null     object
#  6   JOB_ID          50 non-null     object
#  7   SALARY          50 non-null     int64
#  8   COMMISSION_PCT  50 non-null     object
#  9   MANAGER_ID      50 non-null     object
#  10  DEPARTMENT_ID   50 non-null     int64
# dtypes: int64(3), object(8)
# memory usage: 4.4+ KB

# %%
data.isna().sum()
# Out:
# EMPLOYEE_ID       0
# FIRST_NAME        0
# LAST_NAME         0
# EMAIL             0
# PHONE_NUMBER      0
# HIRE_DATE         0
# JOB_ID            0
# SALARY            0
# COMMISSION_PCT    0
# MANAGER_ID        0
# DEPARTMENT_ID     0
# dtype: int64

# %%
data.head()
# Out:
#    EMPLOYEE_ID FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0          198     Donald   OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1          199    Douglas      Grant    DGRANT  650.507.9844  13-JAN-08
# 2          200   Jennifer     Whalen   JWHALEN  515.123.4444  17-SEP-03
# 3          201    Michael  Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 4          202        Pat        Fay      PFAY  603.123.6666  17-AUG-05
#
#      JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# 0  SH_CLERK    2600             -         124             50
# 1  SH_CLERK    2600             -         124             50
# 2   AD_ASST    4400             -         101             10
# 3    MK_MAN   13000             -         100             20
# 4    MK_REP    6000             -         201             20

# %%
data["SALARY"] = data["SALARY"].astype("float")

# %%
package =data.groupby("EMPLOYEE_ID")["SALARY"].mean()
package.plot(kind = "bar")
for i in range(len(package.index)):
  plt.text(i, package[package.index[i]], str( round(package[package.index[i]],1)))

# %%
data["SALARY"].value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
for column in data.columns[1:]:
  if data[column].dtype != "object":
    sns.histplot(data[column],kde = True)
    plt.title(column)
    plt.show()

# %%
data[(data["SALARY"]>0) & (data["SALARY"]<200000) ]["SALARY"].plot(kind = "hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
data[(data["SALARY"]>0) & (data["SALARY"]<17000) ]["SALARY"].plot(kind = "box")
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data['SALARY'], bins=20, kde=True)
plt.title('SALARY_DISTRIBUTION')
plt.xlabel('SALARY')
plt.ylabel('FREQUENCY')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=data, x='JOB_ID')
plt.title('JOB_ID_COUNTS')
plt.xlabel('Job_ID')
plt.ylabel('COUNT')
plt.xticks(rotation=45)
plt.show()
